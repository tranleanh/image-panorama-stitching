# %%
from imutils import paths
import numpy as np
import argparse
import imutils
import cv2

# %%
# !pip install pillow
# Out:
# Collecting pillow
#   Downloading https://files.pythonhosted.org/packages/70/f4/9dd0b7b0fea09cf4e7a2822031f2157f40d41f0252a89558bdb583e24ef1/Pillow-6.2.1-cp37-cp37m-win_amd64.whl (2.0MB)
# Installing collected packages: pillow
# Successfully installed pillow-6.2.1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image1 = mpimg.imread("./images/3_images/pa1.jpg")
image2 = mpimg.imread("./images/3_images/pa2.jpg")
image3 = mpimg.imread("./images/3_images/pa3.jpg")
images = [image1, image2, image3]

# %%
stitcher = cv2.createStitcher() if imutils.is_cv3() else cv2.Stitcher_create()
(status, stitched) = stitcher.stitch(images)

# %%
plt.imshow(stitched)
